# %%
import numpy as np; import pandas as pd; 
import xarray as xr; import sys; import matplotlib.pyplot as plt
# sys.path.insert(0,'/mnt/sda1/PhysOc/modview/modview')
sys.path.insert(0,'D:/Documentos/CUCEI LIFI/Practicas Profesionales/modview/modview-main/modview')
import loader, viztools
# argo_path = '/mnt/sda1/SciData/'
argo_path = '/Argo-Files/'
import os, importlib, datetime
from dateutil.relativedelta import relativedelta

# %% [markdown]
# To describe the process of finding, loading, and visualizing data in modview, below is an example that uses the Roemmich-Gilson Argo climatology (https://sio-argo.ucsd.edu/RG_Climatology.html).
#
# We begin with a description of how this data will be referenced in databases. This helps streamline loading data with the loader.assemble class.

# %%
sys.path.insert(1,'D:/Documentos/CUCEI LIFI/Practicas Profesionales/modview/modview_new/modview') # Location of DB functions
### Check that the DB in DataBase_functions.py has te correct directory (Also check the note about DB3_EDIT)
from DataBase_functions import *


# argo_directory = '/mnt/sda1/SciData/ARGO/
argo_directory = argo_path


ARGO_id = id_maker(project = 'ARGO')
Data = Data_extraction(ARGO_id,0)
ARGO_paths = path_maker(Data, argo_directory)


# '[0]' since ARGO_id is a list with all data that has project name ARGO and the first one (only in this case)
# is the one we're loking for. Should we change Data_extraction to work only with 1 item and do allways an specific query with
# id_maker?

RG_clim = loader.assemble(ARGO_id[0],ARGO_paths)
ARGO_paths.keys()
# Out:
# dict_keys(['ARGO Temperature', 'ARGO Month'])

# %%
#ARGO Temperature contains the mean temperature from 2004-2018 while ARGO Moth have all the months files from 2019-2020
#To have both files in one list we append the mean to the montly files:
ARGO_paths['ARGO Month'].insert(0, ARGO_paths['ARGO Temperature'][0])

# %% [markdown]
# At this point, all information necessary to load data from the RG climatology has been loaded onto the object 'RG_clim,' but the data itself has not been accessed. Depending on how your original files are structured and how you want to structure your own analysis, it is adviseable that you take some time to write the following steps into repeatable functions that give your data the specific format and names that will make analysis easiest.
#
# In this case, to load the data and start working with it, we do:

# %%
# Access the variable 'ARGO_TEMPERATURE_MEAN' in the .nc file and store it as RG_clim.grids['Temp_mean']
RG_clim.store_nc([ARGO_paths['ARGO Temperature'][0]],['ARGO_TEMPERATURE_MEAN'], saveas=['Temp_mean'], decode_times=False)

###
# Currently I'm trying to figure out why I need to input '[0]' for ARGO_paths['ARGO Temperature'] the error occurs in splitext
# since os.path expect only a string and not a list but doing it manually I didn't get any error as I show in the cell below
###

# Now the monthly anomalies
RG_clim.store_nc(ARGO_paths['ARGO Month'],['ARGO_TEMPERATURE_ANOMALY'], saveas=['Temp_month'], decode_times=False)

# %%
for kk in range(len(ARGO_paths['ARGO Temperature'])):
    filename = ARGO_paths['ARGO Temperature'][kk]
    print(os.path.splitext(filename))
# Out:
# ('/Argo-Files/RG_ArgoClim_Temperature_2019', '.nc')

# %%
def cut_argo(item,lon,lat,pres):
    item = item.sel(LONGITUDE=slice(lon[0],lon[1]));
    item = item.sel(LATITUDE=slice(lat[0],lat[1]));
    item = item.sel(PRESSURE=slice(pres[0],pres[1]));
    return item
LON = [100,150]; LAT = [5,25]; PRES = [0,150];

nfiles = len(RG_clim.grids['Temp_month'])
RG_clim.grids['Temp_month'] = [cut_argo(RG_clim.grids['Temp_month'][kk],
                                       LON, LAT, PRES) for kk in range(nfiles)];
RG_clim.grids['Temp_mean'] = cut_argo(RG_clim.grids['Temp_mean'][0], LON, LAT, PRES)

RG_clim.grids['Temp_month'] = xr.concat( RG_clim.grids['Temp_month'], dim='TIME')
RG_clim.grids['Temp_month'] = RG_clim.grids['Temp_month'].sortby('TIME')
# Add mean to have real temperatures
RG_clim.grids['Temp_month'] = RG_clim.grids['Temp_month'] + RG_clim.grids['Temp_mean']

# %% [markdown]
# Monthly temperature anomalies in this dataset are categorized by the number of months since January of 2004. Let us quickly turn those dates into the datetime form. (This is the type of tasks that are specific to individual datasets and should be stored into a set of project-specific functions that interface with loader).

# %% [markdown]
# For this example, we will only focus on upper ocean temperatures in the Western Pacific Ocean. Therefore, we will choose only a subset of the data available.

# %%
base_date = datetime.datetime(2004,1,15);
tlist = RG_clim.grids['Temp_month'].TIME.values;
dt = [base_date + relativedelta(months=+np.floor(nmonths)) for nmonths in tlist]
RG_clim.grids['Temp_month']['TIME'] = dt

# %% [markdown]
# Let's plot the multiannual evolution of SST at 134.7 E, 15.7 N since 2004.

# %%
RG_SIO3 = RG_clim.grids['Temp_month'].sel(PRESSURE=0,method='nearest')
RG_SIO3 = RG_SIO3.sel(LONGITUDE=134.7,method='nearest')
RG_SIO3 = RG_SIO3.sel(LATITUDE=15.7,method='nearest')

# %%
RG_SIO3.sel(TIME=slice('2004','2020')).plot()

# %%
RG_clim.grids['Temp_mean']
# Out:
# <xarray.DataArray 'ARGO_TEMPERATURE_MEAN' (PRESSURE: 16, LATITUDE: 20, LONGITUDE: 50)>
# array([[[   nan,    nan, ..., 29.525, 29.558],
#         [   nan,    nan, ..., 29.49 , 29.498],
#         ...,
#         [   nan,    nan, ..., 27.142, 27.189],
#         [   nan,    nan, ..., 26.708, 26.72 ]],
#
#        [[   nan,    nan, ..., 29.508, 29.54 ],
#         [   nan,    nan, ..., 29.474, 29.48 ],
#         ...,
#         [   nan,    nan, ..., 27.076, 27.13 ],
#         [   nan,    nan, ..., 26.622, 26.645]],
#
#        ...,
#
#        [[   nan,    nan, ..., 21.671, 21.204],
#         [   nan,    nan, ..., 20.699, 20.058],
#         ...,
#         [   nan,    nan, ..., 20.501, 20.596],
#         [   nan,    nan, ..., 19.922, 19.842]],
#
#        [[   nan,    nan, ..., 20.236, 19.767],
#         [   nan,    nan, ..., 19.185, 18.598],
#         ...,
#         [   nan,    nan, ..., 20.063, 20.153],
#         [   nan,    nan, ..., 19.552, 19.474]]], dtype=float32)
# Coordinates:
#   * LONGITUDE  (LONGITUDE) float32 100.5 101.5 102.5 103.5 ... 147.5 148.5 149.5
#   * LATITUDE   (LATITUDE) float32 5.5 6.5 7.5 8.5 9.5 ... 21.5 22.5 23.5 24.5
#   * PRESSURE   (PRESSURE) float32 2.5 10.0 20.0 30.0 ... 120.0 130.0 140.0 150.0
# Attributes:
#     units:      degree celcius (ITS-90)
#     long_name:  ARGO TEMPERATURE MEAN Jan 2004 - Dec 2018 (15.0 year) RG CLIM...
